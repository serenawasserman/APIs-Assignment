# %% [markdown]
# # Working with APIs

# %% [markdown]
# API stands for Application programming interface<br>
# APIs are a way for applications to talk to eachother<br>
# In python we use the requests package to handle the connection<br>
# <small><strong>Note: It is requests with an s not request(this is a different package)</strong></small><br>
# Most API's communicate with data in the form of JSON<br>
# JSON stands for JavaScript Object Notation

# %%
#import the packages we need:
import requests, json

# %% [markdown]
# We will be connecting to the Ergast F1 Racer API today:
# http://ergast.com/mrd/
#
# to view JSON data nicely in the Chrome browser install the extension JSONview

# %%
# help(requests)

# %%
url = 'http://ergast.com/api/f1/2008/5/driverStandings.json'

# %%
#response object
response = requests.get(url)
print(response) #200 means the response worked successfully
# Out:
# <Response [200]>

# %%
#check and make sure we got a successful response from the API
response.ok
# Out:
# True

# %%
#view the response as a JSON
response.json()
# Out:
# {'MRData': {'xmlns': 'http://ergast.com/mrd/1.5',
#   'series': 'f1',
#   'url': 'http://ergast.com/api/f1/2008/5/driverstandings.json',
#   'limit': '30',
#   'offset': '0',
#   'total': '22',
#   'StandingsTable': {'season': '2008',
#    'round': '5',
#    'StandingsLists': [{'season': '2008',
#      'round': '5',
#      'DriverStandings': [{'position': '1',
#        'positionText': '1',
#        'points': '35',
#        'wins': '2',
#        'Driver': {'driverId': 'raikkonen',
#         'permanentNumber': '7',
#         'code': 'RAI',
#         'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#         'givenName': 'Kimi',
#         'familyName': 'Räikkönen',
#         'dateOfBirth': '1979-10-17',
#         'nationality': 'Finnish'},
#        'Constructors': [{'constructorId': 'ferrari',
#          'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#          'name': 'Ferrari',
#          'nationality': 'Italian'}]},
#       {'position': '2',
# ...

# %%
data1 = response.json()["MRData"]["StandingsTable"]["StandingsLists"][0]["DriverStandings"][4]["Constructors"][0]["name"]
data1
# Out:
# 'BMW Sauber'

# %%
type(response.json())
# Out:
# dict

# %%
# We only want the Driver Last Names
#for x in range(5):
#    data = response.json()["MRData"]["StandingsTable"]["StandingsLists"][0]["DriverStandings"][x]["Driver"]["familyName"]
#    print(data)
# Out:
# Räikkönen
# Massa
# Hamilton
# Kubica
# Heidfeld

# %%
#function to get racer info
#step 1: get to driver standings
ds_data = response.json()["MRData"]["StandingsTable"]["StandingsLists"][0]["DriverStandings"]

#step 2: write function
def get_racer_info(ds_data):
    new_data = []
    for racer in ds_data:
        racer_dict = {}
        racer_name = f'{racer["Driver"]["givenName"]} {racer["Driver"]["familyName"]}'
        
        racer_dict[racer_name] = {
            "first_name": racer["Driver"]["givenName"],
            "last_name": racer["Driver"]["familyName"],
            "position": racer["position"],
            "wins": racer["wins"],
            "DOB": racer["Driver"]["dateOfBirth"],
            "nationality": racer["Driver"]["nationality"],
            "constructor": racer["Constructors"][0]["name"]
        }
        new_data.append(racer_dict)
    return new_data

get_racer_info(ds_data)
# Out:
# [{'Kimi Räikkönen': {'first_name': 'Kimi',
#    'last_name': 'Räikkönen',
#    'position': '1',
#    'wins': '2',
#    'DOB': '1979-10-17',
#    'nationality': 'Finnish',
#    'constructor': 'Ferrari'}},
#  {'Felipe Massa': {'first_name': 'Felipe',
#    'last_name': 'Massa',
#    'position': '2',
#    'wins': '2',
#    'DOB': '1981-04-25',
#    'nationality': 'Brazilian',
#    'constructor': 'Ferrari'}},
#  {'Lewis Hamilton': {'first_name': 'Lewis',
#    'last_name': 'Hamilton',
#    'position': '3',
#    'wins': '1',
#    'DOB': '1985-01-07',
#    'nationality': 'British',
#    'constructor': 'McLaren'}},
#  {'Robert Kubica': {'first_name': 'Robert',
#    'last_name': 'Kubica',
#    'position': '4',
#    'wins': '0',
#    'DOB': '1984-12-07',
#    'nationality': 'Polish',
#    'constructor': 'BMW Sauber'}},
#  {'Nick Heidfeld': {'first_name': 'Nick',
#    'last_name': 'Heidfeld',
#    'position': '5',
#    'wins': '0',
#    'DOB': '1977-05-10',
#    'nationality': 'German',
# ...

# %%
def get_driver_info_by_year_and_round(year, round_):
    url = f"http://ergast.com/api/f1/{year}/{round_}/driverStandings.json"
    response = requests.get(url)
    if not response.json()["MRData"]["StandingsTable"]["StandingsLists"]:
        return "We had an error loading your data. It is likely the year or round is not in the database."
    ds_data = response.json()["MRData"]["StandingsTable"]["StandingsLists"][0]["DriverStandings"]
    return get_racer_info(ds_data)

get_driver_info_by_year_and_round(2018, 3)
# Out:
# [{'Sebastian Vettel': {'first_name': 'Sebastian',
#    'last_name': 'Vettel',
#    'position': '1',
#    'wins': '2',
#    'DOB': '1987-07-03',
#    'nationality': 'German',
#    'constructor': 'Ferrari'}},
#  {'Lewis Hamilton': {'first_name': 'Lewis',
#    'last_name': 'Hamilton',
#    'position': '2',
#    'wins': '0',
#    'DOB': '1985-01-07',
#    'nationality': 'British',
#    'constructor': 'Mercedes'}},
#  {'Valtteri Bottas': {'first_name': 'Valtteri',
#    'last_name': 'Bottas',
#    'position': '3',
#    'wins': '0',
#    'DOB': '1989-08-28',
#    'nationality': 'Finnish',
#    'constructor': 'Mercedes'}},
#  {'Daniel Ricciardo': {'first_name': 'Daniel',
#    'last_name': 'Ricciardo',
#    'position': '4',
#    'wins': '1',
#    'DOB': '1989-07-01',
#    'nationality': 'Australian',
#    'constructor': 'Red Bull'}},
#  {'Kimi Räikkönen': {'first_name': 'Kimi',
#    'last_name': 'Räikkönen',
#    'position': '5',
#    'wins': '0',
#    'DOB': '1979-10-17',
# ...

# %% [markdown]
# # <strong>Homework</strong>
# check out this Pokemon API https://pokeapi.co/
# Use the requests package to connect to this API and get and store data for 5 different pokemon.
# Get the pokemons: name, atleast one ability's name, base_experience, and the URL for its sprite (an image that shows up on screen) for the 'front_shiny', attack base_state, hp base_stat, defense base_stat

# %%
def make_pokemon_dict(pokemon):
    url = f"https://pokeapi.co/api/v2/pokemon/{pokemon}"
    response = requests.get(url)
    pokemon_data = response.json()
    
    dictionary = {"name": f"{pokemon}",
            "ability": pokemon_data["abilities"][0]["ability"]["name"],
            "base_experience": pokemon_data["base_experience"],
            "front_shiny": pokemon_data["sprites"]["front_shiny"],
            "attack_base_stat": pokemon_data["stats"][1]["stat"]["url"],
            "hp_base_stat": pokemon_data["stats"][0]["stat"]["url"],
            "defense_base_stat": pokemon_data["stats"][2]["stat"]["url"]}
    
    return dictionary

print(make_pokemon_dict("piplup"))
print("\n")
print(make_pokemon_dict("ivysaur"))
print("\n")
print(make_pokemon_dict("charizard"))
print("\n")
print(make_pokemon_dict("blastoise"))
print("\n")
print(make_pokemon_dict("caterpie"))
print("\n")
print(make_pokemon_dict("metapod"))
print("\n")
print(make_pokemon_dict("butterfree"))
print("\n")
print(make_pokemon_dict("weedle"))
print("\n")
print(make_pokemon_dict("kakuna"))
print("\n")
print(make_pokemon_dict("beedrill"))
print("\n")
print(make_pokemon_dict("pidgey"))
print("\n")
print(make_pokemon_dict("pidgeotto"))
print("\n")
print(make_pokemon_dict("pidgeot"))
print("\n")
print(make_pokemon_dict("rattata"))
print("\n")
print(make_pokemon_dict("raticate"))
print("\n")
print(make_pokemon_dict("spearow"))
print("\n")
print(make_pokemon_dict("fearow"))
print("\n")
print(make_pokemon_dict("ekans"))
print("\n")
print(make_pokemon_dict("arbok"))
print("\n")
print(make_pokemon_dict("sandshrew"))
# Out:
# {'name': 'piplup', 'ability': 'torrent', 'base_experience': 63, 'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/393.png', 'attack_base_stat': 'https://pokeapi.co/api/v2/stat/2/', 'hp_base_stat': 'https://pokeapi.co/api/v2/stat/1/', 'defense_base_stat': 'https://pokeapi.co/api/v2/stat/3/'}
#
#
# {'name': 'ivysaur', 'ability': 'overgrow', 'base_experience': 142, 'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/2.png', 'attack_base_stat': 'https://pokeapi.co/api/v2/stat/2/', 'hp_base_stat': 'https://pokeapi.co/api/v2/stat/1/', 'defense_base_stat': 'https://pokeapi.co/api/v2/stat/3/'}
#
#
# ...
